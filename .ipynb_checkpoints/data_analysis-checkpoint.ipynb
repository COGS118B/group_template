# %%
# things we will need to do stuff in this notebook
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score
from matplotlib.colors import LogNorm
from matplotlib.patches import Ellipse

# two useful data viz libraries
import matplotlib.pyplot as plt
import seaborn as sns

# For finding na values
import missingno as msno

# Make it so more values of the DataFrames and Series are visable
from IPython.display import display

# Assuming your series is named 'series_data'
# Set the maximum number of displayed rows and columns to None to display all data
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
df = pd.read_csv("owid-covid-data.csv", low_memory=False)
df
# Out:
#        iso_code continent     location        date  total_cases  ...  \
# 0           AFG      Asia  Afghanistan  2020-01-05          NaN  ...
# 1           AFG      Asia  Afghanistan  2020-01-06          NaN  ...
# 2           AFG      Asia  Afghanistan  2020-01-07          NaN  ...
# 3           AFG      Asia  Afghanistan  2020-01-08          NaN  ...
# 4           AFG      Asia  Afghanistan  2020-01-09          NaN  ...
# ...         ...       ...          ...         ...          ...  ...
# 376879      ZWE    Africa     Zimbabwe  2024-01-31     266265.0  ...
# 376880      ZWE    Africa     Zimbabwe  2024-02-01     266265.0  ...
# 376881      ZWE    Africa     Zimbabwe  2024-02-02     266265.0  ...
# 376882      ZWE    Africa     Zimbabwe  2024-02-03     266265.0  ...
# 376883      ZWE    Africa     Zimbabwe  2024-02-04     266265.0  ...
#
#         population  excess_mortality_cumulative_absolute  \
# 0       41128772.0                                   NaN
# 1       41128772.0                                   NaN
# 2       41128772.0                                   NaN
# 3       41128772.0                                   NaN
# 4       41128772.0                                   NaN
# ...            ...                                   ...
# 376879  16320539.0                                   NaN
# 376880  16320539.0                                   NaN
# 376881  16320539.0                                   NaN
# 376882  16320539.0                                   NaN
# 376883  16320539.0                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 376879                          NaN               NaN
# 376880                          NaN               NaN
# 376881                          NaN               NaN
# 376882                          NaN               NaN
# 376883                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 376879                                      NaN
# 376880                                      NaN
# 376881                                      NaN
# 376882                                      NaN
# 376883                                      NaN
#
# [376884 rows x 67 columns]

# %% [markdown]
# ## Missing Data Analysis

# %%
msno.matrix(df);

# %%
df.columns

# %%
msno.bar(df);

# %%
msno.heatmap(df);

# %%
sns.set(rc={'figure.figsize':(15,60)})
sns.countplot(df, y='location');

# %%
df['new_cases']

# %%
sns.set(rc={'figure.figsize':(10,8)});
sns.lineplot(data=df, x="date", y="new_cases");

# %% [markdown]
# ## United States Subsection

# %%
df_us = df[df['location']=='United States']
df_us

# %%
sns.set(rc={'figure.figsize':(8,5)});
sns.lineplot(data=df_us, x="date", y="new_deaths_smoothed");

# %% [markdown]
# ## Graph of Deaths

# %%
def death_graph(country):
    df_new = df[df['location'] == country]
    sns.set(rc={'figure.figsize':(8,5)});
    sns.lineplot(data=df_new, x="date", y="new_deaths_smoothed");

# %%
death_graph('Sweden')

# %% [markdown]
# # Function Research

# %%
np.set_printoptions(threshold=np.inf)
df['date'].unique()

# %%
date_one = '2020-03-16'
df_date_one = df[df['date'] == date_one]
df_date_one

# %%
df.columns

# %% [markdown]
# # Function to get all the values from a date

# %%
def clean_data_for_date(df, date):
    """
    Cleans the DataFrame by finding the data from a specified date, indexing by the location 
    and selecting only certain columns
    
    Args:
    df (pd.DataFrame): Input DataFrame.
    date (string): Formatted like YYYY-MM-DD.
    
    Returns:
    pd.DataFrame: Cleaned up DataFrame.
    """
    df = df[df['date'] == date]
    df = df.set_index('location')[
        [
            'total_cases_per_million', 
            'total_deaths_per_million', 
            'reproduction_rate', 
            'icu_patients_per_million', 
            'hosp_patients_per_million',
            'total_tests_per_thousand',
            'new_tests_per_thousand',
            'positive_rate',
            'tests_per_case',
            'total_vaccinations_per_hundred',
            'people_vaccinated_per_hundred',
            'people_fully_vaccinated_per_hundred',
            'total_boosters_per_hundred',
            'stringency_index',
            'population_density',
            'extreme_poverty',
            'cardiovasc_death_rate',
            'handwashing_facilities',
            'hospital_beds_per_thousand',
            'life_expectancy',
            'human_development_index',
            'population'
        ]
    ]
    df = df.drop('World')
    return df[df.isna().sum(axis=1) <= 12]

# %%
df_loc = clean_data_for_date(df, '2020-07-01')
df_loc
# Out:
#              total_cases_per_million  total_deaths_per_million  \
# location
# Afghanistan                  744.394                    17.093
# Albania                      798.292                    17.943
# Algeria                      288.799                    19.598
# Angola                         7.278                     0.281
# Argentina                   1613.810                    76.906
# ...                              ...                       ...
# Venezuela                    168.859                     1.449
# Vietnam                        3.616                       NaN
# Yemen                         32.733                     8.784
# Zambia                        77.182                     1.199
# Zimbabwe                      34.741                     0.613
#
#              reproduction_rate  icu_patients_per_million  \
# location
# Afghanistan               0.82                       NaN
# Albania                   1.18                       NaN
# Algeria                   1.47                       NaN
# Angola                    1.31                       NaN
# Argentina                 1.17                    12.656
# ...                        ...                       ...
# Venezuela                 1.28                       NaN
# Vietnam                   0.34                       NaN
# Yemen                     0.98                       NaN
# Zambia                    0.73                       NaN
# Zimbabwe                  1.39                       NaN
#
#              hosp_patients_per_million  ...  handwashing_facilities  \
# location                                ...
# Afghanistan                        NaN  ...                  37.746
# Albania                            NaN  ...                     NaN
# Algeria                            NaN  ...                  83.741
# Angola                             NaN  ...                  26.664
# Argentina                          NaN  ...                     NaN
# ...                                ...  ...                     ...
# Venezuela                          NaN  ...                     NaN
# Vietnam                            NaN  ...                  85.847
# Yemen                              NaN  ...                  49.542
# Zambia                             NaN  ...                  13.938
# Zimbabwe                           NaN  ...                  36.791
#
#              hospital_beds_per_thousand  life_expectancy  \
# location
# Afghanistan                        0.50            64.83
# Albania                            2.89            78.57
# Algeria                            1.90            76.88
# Angola                              NaN            61.15
# Argentina                          5.00            76.67
# ...                                 ...              ...
# Venezuela                          0.80            72.06
# Vietnam                            2.60            75.40
# Yemen                              0.70            66.12
# Zambia                             2.00            63.89
# Zimbabwe                           1.70            61.49
#
#              human_development_index  population
# location
# Afghanistan                    0.511  41128772.0
# Albania                        0.795   2842318.0
# Algeria                        0.748  44903228.0
# Angola                         0.581  35588996.0
# Argentina                      0.845  45510324.0
# ...                              ...         ...
# Venezuela                      0.711  28301700.0
# Vietnam                        0.704  98186856.0
# Yemen                          0.470  33696612.0
# Zambia                         0.584  20017670.0
# Zimbabwe                       0.571  16320539.0
#
# [171 rows x 22 columns]

# %% [markdown]
# # Normalize Function

# %%
def normalize_columns(df):
    """
    Normalize each column in the DataFrame by dividing each value by the maximum value in that column.
    
    Args:
    df (pd.DataFrame): Input DataFrame.
    
    Returns:
    pd.DataFrame: Normalized DataFrame.
    """
    max_values = df.max()  # Get maximum value for each column
    normalized_df = df.copy()  # Create a copy of the original DataFrame
    
    for column in df.columns:
        normalized_df[column] = df[column] / max_values[column]  # Normalize each column
        
    return normalized_df

# %%
def normalize_columns_zscore(df):
    """
    Normalize each column in the DataFrame by calculating the z-score.
    
    Args:
    df (pd.DataFrame): Input DataFrame.
    
    Returns:
    pd.DataFrame: Normalized DataFrame.
    """
    normalized_df = df.copy()  # Create a copy of the original DataFrame
    
    for column in df.columns:
        mean = df[column].mean()
        std = df[column].std()
        normalized_df[column] = (df[column] - mean) / std  # Calculate z-score for each column
        
    return normalized_df

# %%
normalize_columns_zscore(df_loc)
# Out:
#                               total_cases_per_million  \
# location
# Afghanistan                                 -0.305434
# Albania                                     -0.290543
# Algeria                                     -0.431303
# Angola                                      -0.509079
# Argentina                                   -0.065238
# Armenia                                      1.937686
# Australia                                   -0.430448
# Austria                                     -0.068941
# Azerbaijan                                  -0.101164
# Bahamas                                     -0.441009
# Bahrain                                      4.230398
# Bangladesh                                  -0.288719
# Barbados                                    -0.415940
# Belarus                                      1.259124
# Belgium                                      0.951158
# Belize                                      -0.494730
# Benin                                       -0.487317
# Bhutan                                      -0.484256
# Bolivia                                      0.153890
# Bosnia and Herzegovina                      -0.160956
# Botswana                                    -0.497961
# Brazil                                       1.124855
# Brunei                                      -0.424332
# Bulgaria                                    -0.322684
# Burkina Faso                                -0.499405
# Burundi                                     -0.507446
# Cambodia                                    -0.508800
# Cameroon                                    -0.379013
# Canada                                       0.227349
# Cape Verde                                  -0.002942
# Central African Republic                    -0.311232
# Chad                                        -0.497606
# Chile                                        3.262505
# China                                       -0.494584
# Colombia                                    -0.061365
# Comoros                                     -0.437464
# Congo                                       -0.449592
# Costa Rica                                  -0.359857
# Cote d'Ivoire                               -0.423344
# Croatia                                     -0.331220
# Cuba                                        -0.453678
# Cyprus                                      -0.204602
# Czechia                                     -0.210648
# Democratic Republic of Congo                -0.492043
# Denmark                                      0.085393
# Djibouti                                     0.633341
# Dominican Republic                           0.242258
# Ecuador                                      0.326493
# Egypt                                       -0.351975
# El Salvador                                 -0.261387
# Equatorial Guinea                            0.062103
# Estonia                                      0.995630
# Eswatini                                    -0.339810
# Ethiopia                                    -0.498618
# Fiji                                        -0.505741
# Finland                                     -0.172526
# France                                      -0.433577
# Gabon                                        0.091300
# Gambia                                      -0.506496
# Georgia                                     -0.442914
# Germany                                      0.132266
# Ghana                                       -0.367894
# Greece                                      -0.418883
# Guam                                        -0.125106
# Guatemala                                   -0.266029
# Guinea                                      -0.405619
# Guinea-Bissau                               -0.299317
# Guyana                                      -0.432518
# Haiti                                       -0.374635
# Honduras                                    -0.087552
# Hungary                                     -0.396393
# Iceland                                      0.847668
# India                                       -0.407991
# Indonesia                                   -0.456929
# Iran                                         0.175860
# Iraq                                        -0.242480
# Ireland                                      0.886691
# Israel                                       0.175690
# Italy                                        0.614523
# United Arab Emirates                         -0.245999           0.133865
# United Kingdom                                4.839205          -0.654450
# United States                                 1.951201           0.659408
# United States Virgin Islands                 -0.070714                NaN
# Uruguay                                      -0.408298           0.104668
# Venezuela                                    -0.447660           0.717802
# Vietnam                                            NaN          -2.026703
# Yemen                                        -0.400690          -0.158104
# Zambia                                       -0.449261          -0.888025
# Zimbabwe                                     -0.453014           1.038968
#
#                               icu_patients_per_million  \
# location
# Afghanistan                                        NaN
# Albania                                            NaN
# Algeria                                            NaN
# Angola                                             NaN
# Argentina                                     0.231284
# Armenia                                            NaN
# Australia                                    -0.366146
# Austria                                      -0.327036
# Azerbaijan                                         NaN
# Bahamas                                            NaN
# Bahrain                                            NaN
# Bangladesh                                         NaN
# Barbados                                           NaN
# Belarus                                            NaN
# Belgium                                      -0.227249
# Belize                                             NaN
# Benin                                              NaN
# Bhutan                                             NaN
# Bolivia                                            NaN
# Bosnia and Herzegovina                             NaN
# Botswana                                           NaN
# Brazil                                             NaN
# Brunei                                             NaN
# Bulgaria                                           NaN
# Burkina Faso                                       NaN
# Burundi                                            NaN
# Cambodia                                           NaN
# Cameroon                                           NaN
# Canada                                       -0.266886
# Cape Verde                                         NaN
# Central African Republic                           NaN
# Chad                                               NaN
# Chile                                         4.697797
# China                                              NaN
# Colombia                                           NaN
# Comoros                                            NaN
# Congo                                              NaN
# Costa Rica                                         NaN
# Cote d'Ivoire                                      NaN
# Croatia                                            NaN
# Cuba                                               NaN
# Cyprus                                       -0.375300
# Czechia                                      -0.329624
# Democratic Republic of Congo                       NaN
# Denmark                                      -0.285674
# Djibouti                                           NaN
# Dominican Republic                                 NaN
# Ecuador                                            NaN
# Egypt                                              NaN
# El Salvador                                        NaN
# Equatorial Guinea                                  NaN
# Estonia                                            NaN
# Eswatini                                           NaN
# Ethiopia                                           NaN
# Fiji                                               NaN
# Finland                                      -0.375300
# France                                        0.016277
# Gabon                                              NaN
# Gambia                                             NaN
# Georgia                                            NaN
# Germany                                      -0.187324
# Ghana                                              NaN
# Greece                                             NaN
# Guam                                               NaN
# Guatemala                                          NaN
# Guinea                                             NaN
# Guinea-Bissau                                      NaN
# Guyana                                             NaN
# Haiti                                              NaN
# Honduras                                           NaN
# Hungary                                            NaN
# Iceland                                            NaN
# India                                              NaN
# Indonesia                                          NaN
# Iran                                               NaN
# Iraq                                               NaN
# Ireland                                            NaN
# Israel                                             NaN
# Italy                                        -0.304653
# Jamaica                                            NaN
# Japan                                        -0.359819
# Jordan                                             NaN
# Kazakhstan                                         NaN
# Kenya                                              NaN
# Kuwait                                             NaN
# Kyrgyzstan                                         NaN
# Laos                                               NaN
# Latvia                                             NaN
# Lebanon                                            NaN
# Liberia                                            NaN
# Libya                                              NaN
# Liechtenstein                                      NaN
# Lithuania                                          NaN
# Luxembourg                                   -0.227297
# Madagascar                                         NaN
# Malawi                                             NaN
# Malaysia                                     -0.368255
# Maldives                                           NaN
# Mali                                               NaN
# Malta                                              NaN
# Mauritania                                         NaN
# Mauritius                                          NaN
# Mexico                                             NaN
# Moldova                                            NaN
# Mongolia                                           NaN
# Montenegro                                         NaN
# Morocco                                            NaN
# Mozambique                                         NaN
# Myanmar                                            NaN
# Namibia                                            NaN
# Nepal                                              NaN
# Netherlands                                        NaN
# New Zealand                                        NaN
# Nicaragua                                          NaN
# Niger                                              NaN
# Nigeria                                            NaN
# North Macedonia                                    NaN
# Northern Mariana Islands                           NaN
# Norway                                             NaN
# Oman                                               NaN
# Pakistan                                           NaN
# Palestine                                          NaN
# Panama                                             NaN
# Paraguay                                           NaN
# Peru                                               NaN
# Philippines                                        NaN
# Poland                                             NaN
# Portugal                                     -0.006633
# Puerto Rico                                        NaN
# Qatar                                              NaN
# Romania                                            NaN
# Russia                                             NaN
# Rwanda                                             NaN
# Sao Tome and Principe                              NaN
# Saudi Arabia                                       NaN
# Senegal                                            NaN
# Serbia                                        0.133893
# Sierra Leone                                       NaN
# Singapore                                          NaN
# Slovakia                                     -0.349802
# Slovenia                                     -0.375300
# Somalia                                            NaN
# South Africa                                  0.191264
# South Korea                                  -0.344770
# Spain                                              NaN
# Sri Lanka                                          NaN
# Sudan                                              NaN
# Suriname                                           NaN
# Sweden                                        0.247149
# Switzerland                                  -0.249200
# Syria                                              NaN
# Tajikistan                                         NaN
# Tanzania                                           NaN
# Thailand                                           NaN
# Timor                                              NaN
# Togo                                               NaN
# Trinidad and Tobago                                NaN
# Tunisia                                            NaN
# Turkey                                             NaN
# Uganda                                             NaN
# Ukraine                                            NaN
# United Arab Emirates                               NaN
# United Kingdom                               -0.191398
# United States                                      NaN
# United States Virgin Islands                       NaN
# Uruguay                                            NaN
# Venezuela                                          NaN
# Vietnam                                            NaN
# Yemen                                              NaN
# Zambia                                             NaN
# Zimbabwe                                           NaN
#
#                               hosp_patients_per_million  \
# location
# Afghanistan                                         NaN
# Albania                                             NaN
# Algeria                                             NaN
# Angola                                              NaN
# Argentina                                           NaN
# Armenia                                             NaN
# Australia                                     -0.579659
# Austria                                       -0.445944
# Azerbaijan                                          NaN
# Bahamas                                             NaN
# Bahrain                                             NaN
# Bangladesh                                          NaN
# Barbados                                            NaN
# Belarus                                             NaN
# Belgium                                       -0.279948
# Belize                                              NaN
# Benin                                               NaN
# Bhutan                                              NaN
# Bolivia                                             NaN
# Bosnia and Herzegovina                              NaN
# Botswana                                            NaN
# Brazil                                              NaN
# Brunei                                              NaN
# Bulgaria                                            NaN
# Burkina Faso                                        NaN
# Burundi                                             NaN
# Cambodia                                            NaN
# Cameroon                                            NaN
# Canada                                        -0.258568
# Cape Verde                                          NaN
# Central African Republic                            NaN
# Chad                                                NaN
# Chile                                               NaN
# China                                               NaN
# Colombia                                            NaN
# Comoros                                             NaN
# Congo                                               NaN
# Costa Rica                                          NaN
# Cote d'Ivoire                                       NaN
# Croatia                                       -0.235752
# Cuba                                                NaN
# Cyprus                                        -0.576044
# Czechia                                       -0.466489
# Democratic Republic of Congo                        NaN
# Denmark                                       -0.506761
# Djibouti                                            NaN
# Dominican Republic                                  NaN
# Ecuador                                             NaN
# Egypt                                               NaN
# El Salvador                                         NaN
# Equatorial Guinea                                   NaN
# Estonia                                       -0.582620
# Eswatini                                            NaN
# Ethiopia                                            NaN
# Fiji                                                NaN
# Finland                                       -0.517624
# France                                         1.624639
# Gabon                                               NaN
# Gambia                                              NaN
# Georgia                                             NaN
# Germany                                             NaN
# Ghana                                               NaN
# Greece                                              NaN
# Guam                                                NaN
# Guatemala                                           NaN
# Guinea                                              NaN
# Guinea-Bissau                                       NaN
# Guyana                                              NaN
# Haiti                                               NaN
# Honduras                                            NaN
# Hungary                                             NaN
# Iceland                                             NaN
# India                                               NaN
# Indonesia                                           NaN
# Iran                                                NaN
# Iraq                                                NaN
# Ireland                                             NaN
# Israel                                         0.059236
# Italy                                         -0.254172
# Jamaica                                             NaN
# Japan                                         -0.494318
# Jordan                                              NaN
# Kazakhstan                                          NaN
# Kenya                                               NaN
# Kuwait                                              NaN
# Kyrgyzstan                                          NaN
# Laos                                                NaN
# Latvia                                              NaN
# Lebanon                                             NaN
# Liberia                                             NaN
# Libya                                               NaN
# Liechtenstein                                 -0.596317
# Lithuania                                           NaN
# Luxembourg                                    -0.147504
# Madagascar                                          NaN
# Malawi                                              NaN
# Malaysia                                      -0.557243
# Maldives                                            NaN
# Mali                                                NaN
# Malta                                               NaN
# Mauritania                                          NaN
# Mauritius                                           NaN
# Mexico                                              NaN
# Moldova                                             NaN
# Mongolia                                            NaN
# Montenegro                                          NaN
# Morocco                                             NaN
# Mozambique                                          NaN
# Myanmar                                             NaN
# Namibia                                             NaN
# Nepal                                               NaN
# Netherlands                                         NaN
# New Zealand                                         NaN
# Nicaragua                                           NaN
# Niger                                               NaN
# Nigeria                                             NaN
# North Macedonia                                     NaN
# Northern Mariana Islands                            NaN
# Norway                                        -0.539495
# Oman                                                NaN
# Pakistan                                            NaN
# Palestine                                           NaN
# Panama                                              NaN
# Paraguay                                            NaN
# Peru                                                NaN
# Philippines                                         NaN
# Poland                                         0.280109
# Portugal                                       0.293315
# Puerto Rico                                         NaN
# Qatar                                               NaN
# Romania                                             NaN
# Russia                                              NaN
# Rwanda                                              NaN
# Sao Tome and Principe                               NaN
# Saudi Arabia                                        NaN
# Senegal                                             NaN
# Serbia                                         4.117167
# Sierra Leone                                        NaN
# Singapore                                           NaN
# Slovakia                                      -0.583438
# Slovenia                                      -0.527761
# Somalia                                             NaN
# South Africa                                   1.151866
# South Korea                                         NaN
# Spain                                               NaN
# Sri Lanka                                           NaN
# Sudan                                               NaN
# Suriname                                            NaN
# Sweden                                         0.784689
# Switzerland                                   -0.419658
# Syria                                               NaN
# Tajikistan                                          NaN
# Tanzania                                            NaN
# Thailand                                            NaN
# Timor                                               NaN
# Togo                                                NaN
# Trinidad and Tobago                                 NaN
# Tunisia                                             NaN
# Turkey                                              NaN
# Uganda                                              NaN
# Ukraine                                             NaN
# United Arab Emirates                                NaN
# United Kingdom                                 0.258292
# United States                                       NaN
# United States Virgin Islands                        NaN
# Uruguay                                             NaN
# Venezuela                                           NaN
# Vietnam                                             NaN
# Yemen                                               NaN
# Zambia                                              NaN
# Zimbabwe                                            NaN
#
#                               total_tests_per_thousand  \
# location
# Afghanistan                                        NaN
# Albania                                      -0.589456
# Algeria                                            NaN
# Angola                                             NaN
# Argentina                                    -0.563290
# Armenia                                      -0.132598
# Australia                                     0.628355
# Austria                                       0.254930
# Azerbaijan                                         NaN
# Bahamas                                            NaN
# Bahrain                                       4.517340
# Bangladesh                                   -0.640506
# Barbados                                           NaN
# Belarus                                            NaN
# Belgium                                       0.826517
# Belize                                             NaN
# Benin                                              NaN
# Bhutan                                       -0.258975
# Bolivia                                      -0.616119
# Bosnia and Herzegovina                       -0.307709
# Botswana                                           NaN
# Brazil                                       -0.479016
# Brunei                                             NaN
# Bulgaria                                     -0.421183
# Burkina Faso                                       NaN
# Burundi                                            NaN
# Cambodia                                           NaN
# Cameroon                                           NaN
# Canada                                        0.355748
# Cape Verde                                         NaN
# Central African Republic                           NaN
# Chad                                               NaN
# Chile                                         0.082121
# China                                              NaN
# Colombia                                     -0.496883
# Comoros                                            NaN
# Congo                                              NaN
# Costa Rica                                   -0.615195
# Cote d'Ivoire                                -0.675427
# Croatia                                      -0.431233
# Cuba                                         -0.489631
# Cyprus                                        1.736540
# Czechia                                      -0.558603
# Democratic Republic of Congo                       NaN
# Denmark                                       1.844044
# Djibouti                                           NaN
# Dominican Republic                           -0.509690
# Ecuador                                      -0.611197
# Egypt                                              NaN
# El Salvador                                  -0.349192
# Equatorial Guinea                                  NaN
# Estonia                                       0.601913
# Eswatini                                           NaN
# Ethiopia                                     -0.675151
# Fiji                                         -0.628306
# Finland                                      -0.057353
# France                                       -0.332524
# Gabon                                              NaN
# Gambia                                             NaN
# Georgia                                            NaN
# Germany                                            NaN
# Ghana                                        -0.575463
# Greece                                       -0.287375
# Guam                                          0.627997
# Guatemala                                    -0.655506
# Guinea                                             NaN
# Guinea-Bissau                                      NaN
# Guyana                                             NaN
# Haiti                                              NaN
# Honduras                                           NaN
# Hungary                                      -0.310398
# Iceland                                       1.756337
# India                                        -0.617966
# Indonesia                                          NaN
# Iran                                         -0.438926
# Iraq                                         -0.528370
# ...
# North Macedonia                                 0.560766         0.379247
# Northern Mariana Islands                             NaN         0.503943
# Norway                                          0.275002         1.254773
# Oman                                           -0.565479         0.652517
# Pakistan                                       -0.985720        -0.752304
# Palestine                                            NaN         0.147100
# Panama                                         -0.271311         0.738743
# Paraguay                                       -0.691551         0.173631
# Peru                                           -0.565479         0.503943
# Philippines                                    -0.817623        -0.226988
# Poland                                          1.544129         0.767928
# Portugal                                        0.186752         1.208344
# Puerto Rico                                          NaN         0.949665
# Qatar                                          -0.733575         0.966911
# Romania                                         1.658434         0.412411
# Russia                                          2.145073        -0.047903
# Rwanda                                               NaN        -0.520157
# Nicaragua                                   -0.433787   -0.245597
# Niger                                       -2.177466   -0.124045
# Nigeria                                     -1.226964    1.089821
# North Macedonia                              0.313504   -0.276237
# Northern Mariana Islands                          NaN   -0.289137
# Norway                                       1.513102   -0.255153
# Oman                                         0.569156   -0.260568
# Pakistan                                    -1.108971    1.198903
# Palestine                                   -0.119138   -0.256316
# Panama                                       0.582266   -0.261626
# Paraguay                                     0.011965   -0.246655
# Peru                                         0.333169   -0.074554
# Philippines                                 -0.053587    0.439873
# Poland                                       1.008353   -0.037901
# Portugal                                     0.903470   -0.224628
# Puerto Rico                                       NaN   -0.268923
# Qatar                                        0.798587   -0.272440
# Romania                                      0.667484   -0.165375
# Russia                                       0.641263    0.623874
# Rwanda                                      -1.200744   -0.202502
# Sao Tome and Principe                       -0.663219   -0.288015
# Saudi Arabia                                 0.837918   -0.059664
# Senegal                                     -1.403954   -0.180161
# Serbia                                       0.523269   -0.246082
# Sierra Leone                                -1.797265   -0.235137
# Singapore                                    1.388554   -0.253873
# Slovakia                                     0.877249   -0.253833
# Slovenia                                     1.250895   -0.276071
# Somalia                                           NaN   -0.178388
# South Africa                                -0.112583    0.088556
# South Korea                                  1.244340    0.037573
# Spain                                        1.165677    0.010705
# Sri Lanka                                    0.365945   -0.151662
# Sudan                                       -1.417065    0.006385
# Suriname                                     0.077517   -0.285550
# Sweden                                       1.434440   -0.222870
# Switzerland                                  1.499992   -0.234287
# Syria                                       -1.043419   -0.149812
# Tajikistan                                  -0.381346   -0.226636
# Tanzania                                    -1.292516    0.123923
# Thailand                                     0.333169    0.163049
# Timor                                       -0.787767   -0.280985
# Togo                                        -1.384289   -0.233604
# Trinidad and Tobago                          0.457718   -0.279787
# Tunisia                                      0.090627   -0.211467
# Turkey                                       0.615042    0.249161
# Uganda                                      -1.194189    0.008754
# Ukraine                                      0.346280   -0.038882
# United Arab Emirates                         1.073905   -0.229865
# United Kingdom                               1.349223    0.136617
# United States                                1.309891    1.845586
# United States Virgin Islands                      NaN   -0.288822
# Uruguay                                      0.595377   -0.267848
# Venezuela                                   -0.099473   -0.110831
# Vietnam                                     -0.145359    0.330233
# Yemen                                       -1.679272   -0.076782
# Zambia                                      -0.931981   -0.163113
# Zimbabwe                                    -1.017199   -0.186447

# %%
df_loc.dropna()
# Out:
# Empty DataFrame
# Columns: [total_cases_per_million, total_deaths_per_million, reproduction_rate, icu_patients_per_million, hosp_patients_per_million, total_tests_per_thousand, new_tests_per_thousand, positive_rate, tests_per_case, total_vaccinations_per_hundred, people_vaccinated_per_hundred, people_fully_vaccinated_per_hundred, total_boosters_per_hundred, stringency_index, population_density, extreme_poverty, cardiovasc_death_rate, handwashing_facilities, hospital_beds_per_thousand, life_expectancy, human_development_index, population]
# Index: []

# %% [markdown]
# # t-SNE Research

# %%
from sklearn.manifold import TSNE

tsne_perp_5 = TSNE(
    n_components=2, 
    learning_rate='auto', 
    init='random', 
    perplexity=5, 
    random_state=99
)

tcs = tsne_perp_5.fit_transform(df_loc)
# construct the data frame
tcs = pd.DataFrame(tcs,columns=['c1','c2'])
tcs.index = daily_change.index

plot_components(tcs,'c1','c2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 11
#       1 from sklearn.manifold import TSNE
#       3 tsne_perp_5 = TSNE(
#       4     n_components=2,
#       5     learning_rate='auto',
#    (...)
#       8     random_state=99
#       9 )
# ---> 11 tcs = tsne_perp_5.fit_transform(df_loc)
#      12 # construct the data frame
#      13 tcs = pd.DataFrame(tcs,columns=['c1','c2'])
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1119, in TSNE.fit_transform(self, X, y)
#    1117 self._validate_params()
#    1118 self._check_params_vs_input(X)
# -> 1119 embedding = self._fit(X)
#    1120 self.embedding_ = embedding
#    1121 return self.embedding_
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:854, in TSNE._fit(self, X, skip_num_points)
#     851     self.learning_rate_ = self.learning_rate
#     853 if self.method == "barnes_hut":
# --> 854     X = self._validate_data(
#     855         X,
#     856         accept_sparse=["csr"],
#     857         ensure_min_samples=2,
#     858         dtype=[np.float32, np.float64],
#     859     )
#     860 else:
#     861     X = self._validate_data(
#     862         X, accept_sparse=["csr", "csc", "coo"], dtype=[np.float32, np.float64]
#     863     )
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/base.py:546, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     544     raise ValueError("Validation should be done on X, y or both.")
#     545 elif not no_val_X and no_val_y:
# --> 546     X = check_array(X, input_name="X", **check_params)
#     547     out = X
#     548 elif no_val_X and not no_val_y:
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# TSNE does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
n_samples = 1500
random_state = 42
transformation = [[0.60834549, -0.63667341], [-0.40887718, 0.85253229]]
common_params = {
    "random_state": random_state,
}

# %%
def plot_gmm(gmm, X, ax=None):
    ax = ax or plt.gca()
    labels = gmm.fit(X).predict(X)
    ax.scatter(X[:, 0], X[:, 1], c=labels, s=40, cmap='Set3')
    ax.axis('equal')
    w_factor = 0.2 / gmm.weights_.max()
    
    if gmm.covariance_type=='diag':
        fullc = np.array([ np.diag(x) for x in gmm.covariances_])
    elif gmm.covariance_type=='spherical':
        fullc = np.array([ np.diag([x, x]) for x in gmm.covariances_])
    elif gmm.covariance_type=='tied':
        fullc = np.array( gmm.n_components*[gmm.covariances_])
    elif gmm.covariance_type=='full':
        fullc = gmm.covariances_
    else:
        raise NotImplemented
        
    for pos, covar, w in zip(gmm.means_, fullc, gmm.weights_):
        alph = np.max([w*w_factor, 0.05])
        draw_ellipse(pos, covar, ax=ax, alpha=alph)

# %%
k = 3

# try all the the different covariance_types for GMM
cov = 'full' #your answers here


# fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))

plot_gmm( GaussianMixture(n_components=k-1, covariance_type=cov), df, ax=axs[0,0])
axs[0, 0].set_title("Non-optimal Number of Clusters")

# plot_gmm( GaussianMixture(n_components=k, covariance_type=cov, **common_params), X_aniso,  ax=axs[0,1])
# axs[0, 1].set_title("Anisotropically Distributed Blobs")

# plot_gmm( GaussianMixture(n_components=k, covariance_type=cov, **common_params), X_varied, ax=axs[1,0])
# axs[1, 0].set_title("Unequal Variance")

# plot_gmm( GaussianMixture(n_components=k, covariance_type=cov, **common_params), X_filtered, ax=axs[1,1])
# axs[1, 1].set_title("Unevenly Sized Blobs")

plt.suptitle("GMM clusters").set_y(0.95)
plt.show()
